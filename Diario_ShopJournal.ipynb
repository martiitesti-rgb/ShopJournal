# %% [markdown]
# <a href="https://colab.research.google.com/github/martiitesti-rgb/ShopJournal/blob/main/Diario_ShopJournal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
## 23/04/2026
# Analysing the research papers to highlight what they could be used for:
#Studied the foundations of Recommender Systems:
#Explored the differences between Collaborative Filtering and Content-based filtering.
#
#Analyzed sentiment integration via BERT:
#Researched how to incorporate sentiment analysis into e-commerce recommendation engines.
#
#VADER:
#Examined the VADER model for sentiment scoring, specifically its effectiveness in analyzing social media.
#
#Hybrid Approach:
#I believe a Hybrid and Ensemble-based system would be the most effective strategy to incorporate in our project
#
