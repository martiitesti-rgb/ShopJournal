# %% [markdown]
# <a href="https://colab.research.google.com/github/martiitesti-rgb/ShopJournal/blob/main/Diary_ShopJournal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 23/04/2026
# Analysis of the research papers to highlight what they could be used for:
#
# *   Studied the foundations of Recommender Systems: Explored the differences between Collaborative Filtering and Content-based filtering.
# *   Analyzed sentiment integration via BERT:  Researched how to incorporate sentiment analysis into e-commerce recommendation engines.
#
# *  VADER: Examined the VADER model for sentiment scoring, specifically its effectiveness in analyzing social media.
#
# *   Hybrid Approach:  I believe a Hybrid and Ensemble-based system would be the most effective strategy to incorporate in our project
#
# * I Added to the repository a few lines of code in the file RetrievingReviews.ipynb. I used them to simply load the amazon dataset and i tried to get the first few lines of a specific section. In addition i counted reviews that contained a determined key word, counted how many reviews got 5, 4 stars and so on and i also  retrieved only the ratings, the user_id, asin (the amazon id code) and text of said ratings
#
# ## 24/04/2026
#
# Still analizying the reasearch papers:
#
# - Studying of the alghorithms for the top-N products given a variety of items.
# - Learned about the Session based recommender systems.
#
# In short based on what i read on these papers i think that the project should be developed as a hybrid recommender system, This approach will allow us to combine standard user-item interactions with text-derived signals (such as sentiment and intent extracted from reviews and notes). As for the technical part of it the model-free approach described in the paper could be highly suitable, talking in particular about the memory-based approach (also called the neighborhood approach) since it is easier to analyse and debug.
#
# ## 29/04/2026
#
# In the "Recommender Systems Based on User Reviews: The State of the Art" i found a focus on the type of user profiles that i think would be appropriate for the project, i'm talking about the user profile that splits additionally into three subcategories: term-based, rating and feature preference profile. I also learned more about why reviews add essential information to recommender systems and what key words to retrieve from them.
#
# i also tried to make a small function to incorporate vader in the analisys of the review extracted from the data set, it can be found on the RetrivingReviews.ipynb, but i'm not sure about that since it's my first time attempting something like that.
#
# ## 6/05/2026
# I added to the repository a file called extracting_cues.ipynb. I created a function called extract_cues(query, notes) which i used to extract the information given as input. The aim was to return the compund score, the sentiment label and the intent flags, furthermore i've chosen to return also the list of the recognised keywords.
#
# ##14/05/2026
# - Fixing problems with the extract_cues function.
# - Studying the next step of the project:
#
#       1. How the notes should be generated
#       2. Why it's a must that 2 sets are used
#       3. overall understanding of the algorithms and design choices
#
# ## 26/06/2026
# Writing the files needed for the offline evaluation. I added an .ipynb file with the code that loads the Amazon Grocery and Gourmet Food catalogue, so that the query+note+product triples could be created. I generated a .jsonl file with the candidate pool, and the same candidates are also listed in the labelling.csv file, where I 've done the manual  labelling (how relevant each item is for the given query+note pair).
#
# Although I had several doubts about how the labelling should be done, I followed this pattern: I scored 2 the items whose description closely matched the request in the query and note, 1 the items that matched only partially, and 0 the items that were clearly not relevant.
#
# A known limitation: the candidate pool was built through keyword matching (query and note terms) plus a small random sample. This makes the pool somewhat polarized — keyword-matched items tend to be clearly relevant and random items clearly not — so the labelling has few genuinely ambiguous cases.
